# %%
import numpy as np
import matplotlib.pyplot as plt
from fixed_params import *
from fixed_params.general import *
from fixed_params.propulsion import *
from fixed_params.avionics import *
from fixed_params.flight_track import *
from fixed_params.wing import *
from material_properties import areal_mass
from skopt import gp_minimize
from skopt.space import Real, Integer
from scipy.optimize import brentq

# %% [markdown]
# ## Mission Scoring Functions

# %%
def round_inches(x: float) -> float:
    """
    Round a measurement in inches down to the nearest 0.00, 0.25, 0.50, or 0.75.

    Example:
        10.37 -> 10.25
        5.81  -> 5.75
        7.99  -> 7.75
    """
    # Whole inch part
    whole = int(x)

    # Fractional part
    frac = x - whole

    # Define breakpoints
    targets = [0.00, 0.25, 0.50, 0.75]

    # Find the largest target <= frac
    rounded_frac = max([t for t in targets if t <= frac], default=0.00)

    return whole + rounded_frac

def mission_2(num_passengers, num_cargo, m2_laps, battery_capacity):

    income = (num_passengers * (6 + 2 * m2_laps)) + (num_cargo * (10 + 8 * m2_laps))
    EF = battery_capacity / 100
    cost = m2_laps * (10 + (num_passengers*0.5) + (num_cargo*2)) * EF
    net_income = income - cost
    m2 = 1 + (net_income / 900)
    return m2

def mission_3(banner_length, number_of_laps, wing_span):
    """
    :param banner_length: length in inches
    :param number_of_laps: number of laps
    :param wing_span: span in metres
    :return: mission 3 score with best score of 410
    """
    wing_span_inches = wing_span * 39.3701
    pre = round(wing_span_inches)/12 * 0.05 + 0.75
    RAC = pre if pre >= 0.9 else 0.9
    rounded_banner = round_inches(banner_length)
    m3 = (rounded_banner * number_of_laps / RAC)
    m3_best = 1100
    return 2 + (m3 / m3_best)

# %% [markdown]
# ### --- Utility Functions (Externalized and Parameterized) ---

# %%
def velocity(CL, n, W, S):
    """
    Calculates flight velocity.

    Args:
        CL (float): Lift coefficient.
        n (float): Load factor.
        W (float): Weight (Newtons).
        S (float): Wing area (m^2).

    Returns:
        float: Velocity (m/s).
    """
    return np.sqrt((2 * n * W) / (rho * S * CL))


def power_required(CL, W, CD0, k, S, CD_banner=0):
    """
    Calculates required power for straight and level flight (n=1).

    Args:
        CL (float): Lift coefficient.
        W (float): Weight (Newtons).
        CD0 (float): Zero-lift drag coefficient.
        k (float): Induced drag constant.
        S (float): Wing area (m^2).
        CD_banner (float): Additional banner drag coefficient (default 0).

    Returns:
        float: Required Power (Watts).
    """
    CD = CD0 + CD_banner + k * CL ** 2
    v = velocity(CL, 1, W, S)
    return (CD * W / CL) * v


def find_CL_cruise(W, P_effective, CD0, k, S, CL_min, CL_max, CD_banner=0):
    """
    Finds the lift coefficient for cruise flight where P_effective = P_required.

    Args:
        W (float): Weight (Newtons).
        P_effective (float): Effective motor power (Watts).
        CD0 (float): Zero-lift drag coefficient.
        k (float): Induced drag constant.
        S (float): Wing area (m^2).
        CL_min (float): Minimum searchable lift coefficient.
        CL_max (float): Maximum searchable lift coefficient.
        CD_banner (float): Additional banner drag coefficient (default 0).

    Returns:
        float: Lift coefficient (CL) solution.

    Raises:
        ValueError: If brentq cannot find a root in the specified range.
    """
    # Define the specific power function needed for the search, closing over parameters
    def current_power_required(CL):
        return power_required(CL, W, CD0, k, S, CD_banner)

    CL_grid = np.linspace(CL_min, CL_max, 2000)
    f_vals = P_effective - np.array([current_power_required(CL) for CL in CL_grid])

    # Find bracket where sign changes
    sign_change_indices = np.where(np.sign(f_vals[:-1]) * np.sign(f_vals[1:]) < 0)[0]
    
    if len(sign_change_indices) == 0:
        # If no sign change, return the CL that minimizes the absolute difference
        idx_best = np.argmin(np.abs(f_vals))
        # Note: If min abs difference is still far from zero, the solution is approximate
        return CL_grid[idx_best]

    # Use first bracket found for brentq
    a = CL_grid[sign_change_indices[0]]
    b = CL_grid[sign_change_indices[0] + 1]
    
    try:
        # Pass a lambda that calls the closed-over function
        CL_solution = brentq(lambda CL: P_effective - current_power_required(CL), a, b)
        return CL_solution
    except ValueError as error:
        raise ValueError(f"CL_cruise search error: {error}. Could not find a root between {a:.2f} and {b:.2f}.")


def find_turning_conditions(CL, W, CD0, k, P_effective, S):
    """
    Calculates turning performance (n, V, angle, radius) for a given CL and W.

    Args:
        CL (float): Lift coefficient used for the turn.
        W (float): Weight (Newtons).
        CD0 (float): Zero-lift drag coefficient.
        k (float): Induced drag constant.
        P_effective (float): Effective motor power (Watts).
        S (float): Wing area (m^2).

    Returns:
        tuple: (n_max, v, angle_rad, radius)
    """
    CD = CD0 + k * CL ** 2
    
    # Calculate the power required for straight flight at this CL (A)
    A = (CD * W / CL) * np.sqrt(2.0 * W / (rho * S * CL))
    
    # Calculate the maximum load factor (n_max) possible with P_effective
    n_max = (P_effective / A) ** (2.0 / 3.0) 
    
    # Calculate velocity at n_max
    v = velocity(CL, n_max, W, S)
    
    # Calculate bank angle (rad) and turn radius
    angle = np.arccos(1 / n_max) 
    radius = v ** 2 / (g * np.tan(angle))
    
    return n_max, v, angle, radius


def flight_time_one_lap(radius, v_straight, v_turn):
    """
    Calculates time for one lap of the track.

    Args:
        radius (float): Turn radius (m).
        v_straight (float): Cruise velocity (m/s).
        v_turn (float): Turning velocity (m/s).
        straight_distance (float): Length of the straight segment (m).

    Returns:
        float: Time for one lap (seconds).
    """
    # Assuming turning segment is 4*pi*r total distance (2 turns of 2*pi*r each)
    TURNING_DISTANCE_RATIO = 2 * (2 * np.pi) 
    
    # The original logic included a multiplier of 1.5
    total_time = (straight_distance / v_straight + TURNING_DISTANCE_RATIO * radius / v_turn) * 1.5
    return total_time

# %% [markdown]
# ## Combined Mission Objective Function

# %%
def objective_total(x):
    """
    Calculates the combined (negative) score for Mission 2 and Mission 3.

    Args:
        x (tuple/array): Decision variables (WS, pucks, PC_ratio, banner_length, 
                         banner_AR, m2_fly_time, m3_fly_time).
    """
    # Unpack decision variables
    WS, pucks, PC_ratio, banner_length, banner_AR, m2_fly_time, m3_fly_time = x
    
    # Constants
    TIME_TO = 30  # secs
    TIME_LANDING = 30  # secs
    STRUCTURE_RATIO = 1.5
    USABLE_ENERGY = 0.8
    
    # Derived Payload Calculations
    m_duck = general.duck
    m_puck = general.puck
    ducks = pucks * PC_ratio
    
    m2_payload = pucks * m_puck + ducks * m_duck
    
    # Banner calculations
    banner_length_m = banner_length * 0.0254  # inches to meters
    banner_width = banner_length / banner_AR
    banner_width_m = banner_width * 0.0254
    area_banner = banner_length_m * banner_width_m
    m3_payload = 1.2 * area_banner * areal_mass.lightweight_ripstop
    
    payload = max(m2_payload, m3_payload)
    
    # Total Mass (m_total) and Power Calculations
    m = (1 + STRUCTURE_RATIO) * payload
    m_struct = payload * STRUCTURE_RATIO
    power = general.power_ratio * m
    P_effective = power * motor_eff

    # Battery and Motor Mass (based on Mission 2 flight time as the limiting case)
    # The battery is sized for the maximum required flight time across both missions.
    # Since m2_fly_time and m3_fly_time are decision variables, we'll size for m2_time_flight.
    # NOTE: You should ensure the sizing covers the maximum of (m2_time_flight, m3_time_flight).
    m2_total_time = m2_fly_time + TIME_LANDING + TIME_TO
    m3_total_time = m3_fly_time + TIME_LANDING + TIME_TO
    max_total_time = max(m2_total_time, m3_total_time)
    
    m_motor = power / propulsion.power_density
    m_battery = power * (max_total_time / 3600 / USABLE_ENERGY / avionics.energy_density)
    
    # Mission 2 battery capacity check (original code used m2_time_flight, preserving this for now)
    battery_cap_m2 = power * (m2_total_time / 3600 / USABLE_ENERGY)
    if battery_cap_m2 > 100:
        return 1e6 # Large penalty for capacity over 100 Wh
    
    # Mission 3 battery capacity check (original code used m2_time_flight, preserving this for now)
    battery_cap_m3 = power * (m3_total_time / 3600 / USABLE_ENERGY)
    if battery_cap_m3 > 100:
        return 1e6 # Large penalty for capacity over 100 Wh

    # Wing Geometry
    S = m / wing.wing_loading
    c = S / WS
    AR = WS ** 2 / S

    # Aerodynamic Constants
    CD0 = 0.13 + 0.01 * np.sqrt(ducks)
    k = 1 / (np.pi * AR * e)

    # ------------------------------------------------
    # --- MISSION 2 CALCULATIONS ---
    # ----------------------------------------------------
    
    m_2 = m_struct + m2_payload
    W_2 = m_2 * g

    
    try:
        # Turning performance
        n_turning_2, v_turning_2, bank_angle_rad2, turn_radius_2 = find_turning_conditions(CL_turn, W_2, CD0, k, P_effective, S)
        
        # Cruise performance
        CL_cruise_2 = find_CL_cruise(W_2, P_effective, CD0, k, S, CL_min, CL_max)
        V_cruise_2 = velocity(CL_cruise_2, 1, W_2, S)

        
    except ValueError as error:
        # Penalize if cruise/turning conditions cannot be met
        print(f"M2 Flight Error: {error}")
        return 1e6

    # Laps calculation
    one_lap_time_2 = flight_time_one_lap(turn_radius_2, V_cruise_2, v_turning_2)
    number_of_laps_2 = m2_fly_time // one_lap_time_2
    
    if number_of_laps_2 == 0:
        return 1e6
    
    # Scoring
    try:
        m2_score = mission_2(ducks, pucks, number_of_laps_2, battery_cap_m2)
        if not np.isfinite(m2_score):
            return 1e6

    except Exception as error:
        print(f"M2 Scoring Error: {error}")
        return 1e6
    
    # ----------------------------------------------------
    # --- MISSION 3 CALCULATIONS ---
    # ----------------------------------------------------
    
    m_3 = m_struct + m3_payload
    W_3 = m_3 * g

    # Power required function for M3 (with banner drag)
    CD_banner = 0.5 * np.power(banner_AR, -0.5)
    
    try:
        # Turning performance
        n_turning_3, v_turning_3, bank_angle_rad3, turn_radius_3 = find_turning_conditions(CL_turn, W_3, CD0, k, P_effective, S)
        
        # Cruise performance
        CL_cruise_3 = find_CL_cruise(W_3, P_effective, CD0, k, S, CL_min, CL_max, CD_banner=CD_banner)
        V_cruise_3 = velocity(CL_cruise_3, 1, W_3, S)

        
    except ValueError as error:
        # Penalize if cruise/turning conditions cannot be met
        print(f"M3 Flight Error: {error}")
        return 1e6

    # Laps calculation
    one_lap_time_3 = flight_time_one_lap(turn_radius_3, V_cruise_3, v_turning_3)
    number_of_laps_3 = m3_fly_time // one_lap_time_3
    
    if number_of_laps_3 == 0:
        return 1e6
    
    # Scoring
    try:
        m3_score = mission_3(banner_length, number_of_laps_3, WS)
        if not np.isfinite(m3_score):
            return 1e6
        
    except Exception as error:
        print(f"M3 Scoring Error: {error}")
        return 1e6
    print()
    print("############ General Plane Dimensions ###############")
    print(f"WS: {WS:.2f}")
    print(f"Chord: {c:.2f}")
    print(f"Aspect Ratio: {AR:.2f}")
    print(f"Motor Power: {power:.1f}") # Use 1 decimal for power, maybe
    print(f"CDO: {CD0:.4f}") # Use 4 decimals for CD0, as it's a small coefficient
    print()
    print("############ MISSION INPUTS ###############")
    # Integers don't need formatting, but floats will be formatted
    print(f"Mission 2: Ducks = {ducks}, Pucks = {pucks}, payload = {m2_payload:.2f} kg, Battery Cap = {battery_cap_m2:.0f} Wh")
    # The banner length is already in inches, but formatting the float
    print(f"Mission 3: Banner Length (Inches)= {banner_length:.1f}, Banner AR = {banner_AR:.1f}, payload = {m3_payload:.2f} kg, Battery Cap = {battery_cap_m3:.0f} Wh")
    print()
    print("############ MISSION 2 ##############")
    print(f"CL_cruise: {CL_cruise_2:.3f}")
    print(f"V_cruise: {V_cruise_2:.2f} m/s")
    print(f"n_turning: {n_turning_2:.2f}")
    print(f"v_turning: {v_turning_2:.2f} m/s")
    # np.degrees() returns a float, so we format the whole expression
    print(f"bank_angle: {np.degrees(bank_angle_rad2):.2f} degrees")
    print(f"turn_radius: {turn_radius_2:.2f} m")
    print(f"number_of_laps: {number_of_laps_2}") # Integer
    print(f"m2_score: {m2_score:.2f}")
    print()
    print("############ MISSION 3 ##############")
    print(f"CL_cruise: {CL_cruise_3:.3f}")
    print(f"V_cruise: {V_cruise_3:.2f} m/s")
    print(f"n_turning: {n_turning_3:.2f}")
    print(f"v_turning: {v_turning_3:.2f} m/s")
    print(f"bank_angle: {np.degrees(bank_angle_rad3):.2f} degrees")
    print(f"turn_radius: {turn_radius_3:.2f} m")
    print(f"number_of_laps: {number_of_laps_3}") # Integer
    print(f"m3_score: {m3_score:.2f}")
    
    # Final Objective (Minimizing negative score)
    final_score = (m3_score + m2_score)
    print()
    print("FINAL M2 + M3 SCORE: ", final_score)
    return - (m3_score + m2_score)

# %% [markdown]
# ## Optimisation

# %%
#WS, pucks, PC_ratio, banner_length, banner_AR, m2_fly_time, m3_fly_time
search_space = [
    Real(0.9, 1.52, name="wing_span"),      # m
    Integer(1, 30, name="pucks"),
    Integer(3, 15, name="passenger_cargo_ratio"),
    Integer(10, 1000, name="banner_length"), #inch
    Integer(1, 5, name="banner_AR"),
    Integer(45, 270, name="m2_fly_time"), #s
    Integer(45, 270, name="m3_fly_time") #s
]

# Run Bayesian Optimization
result = gp_minimize(
    objective_total,
    search_space,
    n_calls=150,
    n_initial_points=10,
    random_state=42
)

# Best design
best_params = result.x
#WS, pucks, PC_ratio, banner_length, banner_AR, m2_fly_time, m3_fly_time
print("Best parameters found:", best_params)
objective_total(best_params)
# Out:
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.07
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 38 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.39
# v_turning: 26.72 m/s
# bank_angle: 76.84 degrees
# turn_radius: 17.01 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.04 m/s
# n_turning: 3.18
# v_turning: 26.72 m/s
# bank_angle: 71.69 degrees
# turn_radius: 24.08 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.839154946861761
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.15
# Aspect Ratio: 7.83
# Motor Power: 468.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 40 Wh
# Mission 3: Banner Length (Inches)= 254.0, Banner AR = 4.0, payload = 0.94 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.41 m/s
# n_turning: 4.40
# v_turning: 26.65 m/s
# bank_angle: 76.86 degrees
# turn_radius: 16.89 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.17
# v_turning: 26.65 m/s
# bank_angle: 71.60 degrees
# turn_radius: 24.09 m
# number_of_laps: 3.0
# m3_score: 2.74
#
# FINAL M2 + M3 SCORE:  3.852461052407424
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.15
# Aspect Ratio: 7.82
# Motor Power: 468.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 40 Wh
# Mission 3: Banner Length (Inches)= 254.0, Banner AR = 4.0, payload = 0.94 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.41 m/s
# n_turning: 4.40
# v_turning: 26.65 m/s
# bank_angle: 76.86 degrees
# turn_radius: 16.89 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.17
# v_turning: 26.65 m/s
# bank_angle: 71.59 degrees
# turn_radius: 24.09 m
# number_of_laps: 3.0
# m3_score: 2.74
#
# FINAL M2 + M3 SCORE:  3.852461052407424
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.05
# Aspect Ratio: 23.12
# Motor Power: 159.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 14 Wh
# Mission 3: Banner Length (Inches)= 148.0, Banner AR = 4.0, payload = 0.32 kg, Battery Cap = 16 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.250
# V_cruise: 29.23 m/s
# n_turning: 3.74
# v_turning: 28.29 m/s
# bank_angle: 74.51 degrees
# turn_radius: 22.60 m
# number_of_laps: 4.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.500
# V_cruise: 21.18 m/s
# n_turning: 3.57
# v_turning: 28.29 m/s
# bank_angle: 73.72 degrees
# turn_radius: 23.81 m
# number_of_laps: 3.0
# m3_score: 2.43
#
# FINAL M2 + M3 SCORE:  3.5614924081354546
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.22
# Aspect Ratio: 5.10
# Motor Power: 715.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 61 Wh
# Mission 3: Banner Length (Inches)= 314.0, Banner AR = 4.0, payload = 1.43 kg, Battery Cap = 73 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 27.58 m/s
# n_turning: 4.30
# v_turning: 25.56 m/s
# bank_angle: 76.54 degrees
# turn_radius: 15.94 m
# number_of_laps: 4.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.513
# V_cruise: 20.91 m/s
# n_turning: 2.91
# v_turning: 25.56 m/s
# bank_angle: 69.94 degrees
# turn_radius: 24.33 m
# number_of_laps: 3.0
# m3_score: 2.91
#
# FINAL M2 + M3 SCORE:  4.013035567152879
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.17
# Aspect Ratio: 6.50
# Motor Power: 556.9
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 45 Wh
# Mission 3: Banner Length (Inches)= 277.0, Banner AR = 4.0, payload = 1.11 kg, Battery Cap = 57 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.03 m/s
# n_turning: 4.37
# v_turning: 26.21 m/s
# bank_angle: 76.78 degrees
# turn_radius: 16.45 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.509
# V_cruise: 20.99 m/s
# n_turning: 3.06
# v_turning: 26.21 m/s
# bank_angle: 70.96 degrees
# turn_radius: 24.18 m
# number_of_laps: 3.0
# m3_score: 2.81
#
# FINAL M2 + M3 SCORE:  3.9010684630683814
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.13
# Aspect Ratio: 8.76
# Motor Power: 418.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 35 Wh
# Mission 3: Banner Length (Inches)= 240.0, Banner AR = 4.0, payload = 0.84 kg, Battery Cap = 43 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.69 m/s
# n_turning: 4.39
# v_turning: 26.89 m/s
# bank_angle: 76.84 degrees
# turn_radius: 17.23 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.22
# v_turning: 26.89 m/s
# bank_angle: 71.93 degrees
# turn_radius: 24.04 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.8146657361818184
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.17
# Aspect Ratio: 6.90
# Motor Power: 529.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 45 Wh
# Mission 3: Banner Length (Inches)= 270.0, Banner AR = 4.0, payload = 1.06 kg, Battery Cap = 54 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.13 m/s
# n_turning: 4.39
# v_turning: 26.36 m/s
# bank_angle: 76.83 degrees
# turn_radius: 16.57 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.508
# V_cruise: 21.00 m/s
# n_turning: 3.10
# v_turning: 26.36 m/s
# bank_angle: 71.17 degrees
# turn_radius: 24.15 m
# number_of_laps: 3.0
# m3_score: 2.79
#
# FINAL M2 + M3 SCORE:  3.895569524579545
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.07
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 37 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.39
# v_turning: 26.72 m/s
# bank_angle: 76.84 degrees
# turn_radius: 17.01 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.04 m/s
# n_turning: 3.18
# v_turning: 26.72 m/s
# bank_angle: 71.69 degrees
# turn_radius: 24.08 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.8237036536379767
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.15
# Aspect Ratio: 7.66
# Motor Power: 475.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 40 Wh
# Mission 3: Banner Length (Inches)= 256.0, Banner AR = 4.0, payload = 0.95 kg, Battery Cap = 48 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.37 m/s
# n_turning: 4.40
# v_turning: 26.60 m/s
# bank_angle: 76.85 degrees
# turn_radius: 16.85 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.16
# v_turning: 26.60 m/s
# bank_angle: 71.53 degrees
# turn_radius: 24.10 m
# number_of_laps: 3.0
# m3_score: 2.74
#
# FINAL M2 + M3 SCORE:  3.8578610899006063
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.15
# Aspect Ratio: 7.63
# Motor Power: 479.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 40 Wh
# Mission 3: Banner Length (Inches)= 257.0, Banner AR = 4.0, payload = 0.96 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.35 m/s
# n_turning: 4.40
# v_turning: 26.59 m/s
# bank_angle: 76.86 degrees
# turn_radius: 16.83 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.15
# v_turning: 26.59 m/s
# bank_angle: 71.51 degrees
# turn_radius: 24.10 m
# number_of_laps: 3.0
# m3_score: 2.75
#
# FINAL M2 + M3 SCORE:  3.8606708480110514
#
# ############ General Plane Dimensions ###############
# WS: 1.16
# Chord: 0.14
# Aspect Ratio: 8.05
# Motor Power: 464.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 39 Wh
# Mission 3: Banner Length (Inches)= 253.0, Banner AR = 4.0, payload = 0.93 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.43 m/s
# n_turning: 4.41
# v_turning: 26.71 m/s
# bank_angle: 76.91 degrees
# turn_radius: 16.91 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.04 m/s
# n_turning: 3.18
# v_turning: 26.71 m/s
# bank_angle: 71.68 degrees
# turn_radius: 24.08 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.8465031666564418
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.13
# Aspect Ratio: 8.90
# Motor Power: 404.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 34 Wh
# Mission 3: Banner Length (Inches)= 236.0, Banner AR = 4.0, payload = 0.81 kg, Battery Cap = 42 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.78 m/s
# n_turning: 4.37
# v_turning: 26.92 m/s
# bank_angle: 76.79 degrees
# turn_radius: 17.34 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.06 m/s
# n_turning: 3.23
# v_turning: 26.92 m/s
# bank_angle: 71.98 degrees
# turn_radius: 24.04 m
# number_of_laps: 3.0
# m3_score: 2.69
#
# FINAL M2 + M3 SCORE:  3.803900284782121
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.12
# Aspect Ratio: 9.43
# Motor Power: 390.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 232.0, Banner AR = 4.0, payload = 0.78 kg, Battery Cap = 40 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.87 m/s
# n_turning: 4.38
# v_turning: 27.03 m/s
# bank_angle: 76.81 degrees
# turn_radius: 17.46 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.26
# v_turning: 27.03 m/s
# bank_angle: 72.13 degrees
# turn_radius: 24.02 m
# number_of_laps: 3.0
# m3_score: 2.67
#
# FINAL M2 + M3 SCORE:  3.7927537588757576
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.13
# Aspect Ratio: 9.03
# Motor Power: 397.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 34 Wh
# Mission 3: Banner Length (Inches)= 234.0, Banner AR = 4.0, payload = 0.79 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.83 m/s
# n_turning: 4.37
# v_turning: 26.95 m/s
# bank_angle: 76.77 degrees
# turn_radius: 17.40 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.06 m/s
# n_turning: 3.24
# v_turning: 26.95 m/s
# bank_angle: 72.01 degrees
# turn_radius: 24.03 m
# number_of_laps: 3.0
# m3_score: 2.68
#
# FINAL M2 + M3 SCORE:  3.798188305708523
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.12
# Aspect Ratio: 9.34
# Motor Power: 394.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 233.0, Banner AR = 4.0, payload = 0.79 kg, Battery Cap = 40 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.85 m/s
# n_turning: 4.38
# v_turning: 27.01 m/s
# bank_angle: 76.81 degrees
# turn_radius: 17.43 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.25
# v_turning: 27.01 m/s
# bank_angle: 72.10 degrees
# turn_radius: 24.02 m
# number_of_laps: 3.0
# m3_score: 2.68
#
# FINAL M2 + M3 SCORE:  3.7955626550927652
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.11
# Aspect Ratio: 10.33
# Motor Power: 354.5
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 30 Wh
# Mission 3: Banner Length (Inches)= 221.0, Banner AR = 4.0, payload = 0.71 kg, Battery Cap = 37 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 29.16 m/s
# n_turning: 4.35
# v_turning: 27.20 m/s
# bank_angle: 76.72 degrees
# turn_radius: 17.81 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.30
# v_turning: 27.20 m/s
# bank_angle: 72.36 degrees
# turn_radius: 23.98 m
# number_of_laps: 3.0
# m3_score: 2.64
#
# FINAL M2 + M3 SCORE:  3.7628869468136745
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.10
# Aspect Ratio: 11.24
# Motor Power: 320.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 27 Wh
# Mission 3: Banner Length (Inches)= 210.0, Banner AR = 4.0, payload = 0.64 kg, Battery Cap = 33 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.204
# V_cruise: 29.21 m/s
# n_turning: 4.30
# v_turning: 27.35 m/s
# bank_angle: 76.56 degrees
# turn_radius: 18.22 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.10 m/s
# n_turning: 3.34
# v_turning: 27.35 m/s
# bank_angle: 72.56 degrees
# turn_radius: 23.96 m
# number_of_laps: 3.0
# m3_score: 2.61
#
# FINAL M2 + M3 SCORE:  3.732830498034091
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.10
# Aspect Ratio: 11.00
# Motor Power: 326.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 28 Wh
# Mission 3: Banner Length (Inches)= 212.0, Banner AR = 4.0, payload = 0.65 kg, Battery Cap = 33 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.203
# V_cruise: 29.21 m/s
# n_turning: 4.31
# v_turning: 27.31 m/s
# bank_angle: 76.59 degrees
# turn_radius: 18.14 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.10 m/s
# n_turning: 3.33
# v_turning: 27.31 m/s
# bank_angle: 72.51 degrees
# turn_radius: 23.97 m
# number_of_laps: 3.0
# m3_score: 2.62
#
# FINAL M2 + M3 SCORE:  3.7382271753189396
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.20
# Aspect Ratio: 5.84
# Motor Power: 623.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 53 Wh
# Mission 3: Banner Length (Inches)= 293.0, Banner AR = 4.0, payload = 1.25 kg, Battery Cap = 63 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 27.81 m/s
# n_turning: 4.35
# v_turning: 25.94 m/s
# bank_angle: 76.70 degrees
# turn_radius: 16.21 m
# number_of_laps: 4.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.511
# V_cruise: 20.96 m/s
# n_turning: 3.00
# v_turning: 25.94 m/s
# bank_angle: 70.53 degrees
# turn_radius: 24.24 m
# number_of_laps: 3.0
# m3_score: 2.85
#
# FINAL M2 + M3 SCORE:  3.9568817617630114
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.19
# Aspect Ratio: 5.95
# Motor Power: 610.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 52 Wh
# Mission 3: Banner Length (Inches)= 290.0, Banner AR = 4.0, payload = 1.22 kg, Battery Cap = 62 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 27.85 m/s
# n_turning: 4.35
# v_turning: 25.99 m/s
# bank_angle: 76.72 degrees
# turn_radius: 16.25 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.510
# V_cruise: 20.96 m/s
# n_turning: 3.01
# v_turning: 25.99 m/s
# bank_angle: 70.61 degrees
# turn_radius: 24.23 m
# number_of_laps: 3.0
# m3_score: 2.84
#
# FINAL M2 + M3 SCORE:  3.948736063813447
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.12
# Aspect Ratio: 9.49
# Motor Power: 380.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 32 Wh
# Mission 3: Banner Length (Inches)= 229.0, Banner AR = 4.0, payload = 0.76 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.95 m/s
# n_turning: 4.36
# v_turning: 27.04 m/s
# bank_angle: 76.76 degrees
# turn_radius: 17.55 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.26
# v_turning: 27.04 m/s
# bank_angle: 72.15 degrees
# turn_radius: 24.01 m
# number_of_laps: 3.0
# m3_score: 2.67
#
# FINAL M2 + M3 SCORE:  3.784948189614214
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.09
# Aspect Ratio: 12.69
# Motor Power: 287.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 25 Wh
# Mission 3: Banner Length (Inches)= 199.0, Banner AR = 4.0, payload = 0.57 kg, Battery Cap = 29 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.209
# V_cruise: 29.21 m/s
# n_turning: 4.26
# v_turning: 27.55 m/s
# bank_angle: 76.41 degrees
# turn_radius: 18.70 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.12 m/s
# n_turning: 3.38
# v_turning: 27.55 m/s
# bank_angle: 72.81 degrees
# turn_radius: 23.93 m
# number_of_laps: 3.0
# m3_score: 2.58
#
# FINAL M2 + M3 SCORE:  3.7024752410483615
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.38
# Motor Power: 435.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 37 Wh
# Mission 3: Banner Length (Inches)= 245.0, Banner AR = 4.0, payload = 0.87 kg, Battery Cap = 44 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.58 m/s
# n_turning: 4.39
# v_turning: 26.79 m/s
# bank_angle: 76.84 degrees
# turn_radius: 17.11 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.20
# v_turning: 26.79 m/s
# bank_angle: 71.80 degrees
# turn_radius: 24.06 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8279186025866476
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.12
# Aspect Ratio: 9.53
# Motor Power: 377.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 32 Wh
# Mission 3: Banner Length (Inches)= 228.0, Banner AR = 4.0, payload = 0.75 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.97 m/s
# n_turning: 4.36
# v_turning: 27.05 m/s
# bank_angle: 76.74 degrees
# turn_radius: 17.58 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.26
# v_turning: 27.05 m/s
# bank_angle: 72.16 degrees
# turn_radius: 24.01 m
# number_of_laps: 3.0
# m3_score: 2.66
#
# FINAL M2 + M3 SCORE:  3.7817001091277276
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.11
# Aspect Ratio: 10.32
# Motor Power: 354.5
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 30 Wh
# Mission 3: Banner Length (Inches)= 221.0, Banner AR = 4.0, payload = 0.71 kg, Battery Cap = 37 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 29.16 m/s
# n_turning: 4.35
# v_turning: 27.20 m/s
# bank_angle: 76.72 degrees
# turn_radius: 17.81 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.30
# v_turning: 27.20 m/s
# bank_angle: 72.36 degrees
# turn_radius: 23.98 m
# number_of_laps: 3.0
# m3_score: 2.64
#
# FINAL M2 + M3 SCORE:  3.7628869468136745
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.13
# Aspect Ratio: 8.88
# Motor Power: 407.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 34 Wh
# Mission 3: Banner Length (Inches)= 237.0, Banner AR = 4.0, payload = 0.82 kg, Battery Cap = 42 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.76 m/s
# n_turning: 4.38
# v_turning: 26.91 m/s
# bank_angle: 76.80 degrees
# turn_radius: 17.32 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.23
# v_turning: 26.91 m/s
# bank_angle: 71.97 degrees
# turn_radius: 24.04 m
# number_of_laps: 3.0
# m3_score: 2.69
#
# FINAL M2 + M3 SCORE:  3.806522691116733
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.10
# Aspect Ratio: 11.61
# Motor Power: 314.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 27 Wh
# Mission 3: Banner Length (Inches)= 208.0, Banner AR = 4.0, payload = 0.63 kg, Battery Cap = 32 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.205
# V_cruise: 29.21 m/s
# n_turning: 4.30
# v_turning: 27.41 m/s
# bank_angle: 76.56 degrees
# turn_radius: 18.30 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.11 m/s
# n_turning: 3.35
# v_turning: 27.41 m/s
# bank_angle: 72.63 degrees
# turn_radius: 23.95 m
# number_of_laps: 3.0
# m3_score: 2.61
#
# FINAL M2 + M3 SCORE:  3.727209654530909
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.14
# Aspect Ratio: 7.90
# Motor Power: 453.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 39 Wh
# Mission 3: Banner Length (Inches)= 250.0, Banner AR = 4.0, payload = 0.91 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.48 m/s
# n_turning: 4.38
# v_turning: 26.67 m/s
# bank_angle: 76.81 degrees
# turn_radius: 16.99 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.04 m/s
# n_turning: 3.17
# v_turning: 26.67 m/s
# bank_angle: 71.62 degrees
# turn_radius: 24.09 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.8411261061789777
#
# ############ General Plane Dimensions ###############
# WS: 1.12
# Chord: 0.10
# Aspect Ratio: 11.48
# Motor Power: 308.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 26 Wh
# Mission 3: Banner Length (Inches)= 206.0, Banner AR = 4.0, payload = 0.62 kg, Battery Cap = 32 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.206
# V_cruise: 29.21 m/s
# n_turning: 4.28
# v_turning: 27.39 m/s
# bank_angle: 76.48 degrees
# turn_radius: 18.39 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.11 m/s
# n_turning: 3.35
# v_turning: 27.39 m/s
# bank_angle: 72.61 degrees
# turn_radius: 23.95 m
# number_of_laps: 3.0
# m3_score: 2.60
#
# FINAL M2 + M3 SCORE:  3.724622905146802
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.20
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 38 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.40
# v_turning: 26.75 m/s
# bank_angle: 76.86 degrees
# turn_radius: 17.03 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.04 m/s
# n_turning: 3.19
# v_turning: 26.75 m/s
# bank_angle: 71.74 degrees
# turn_radius: 24.07 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.836241262547879
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.12
# Aspect Ratio: 9.57
# Motor Power: 377.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 228.0, Banner AR = 4.0, payload = 0.75 kg, Battery Cap = 38 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.97 m/s
# n_turning: 4.36
# v_turning: 27.06 m/s
# bank_angle: 76.75 degrees
# turn_radius: 17.58 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.08 m/s
# n_turning: 3.27
# v_turning: 27.06 m/s
# bank_angle: 72.17 degrees
# turn_radius: 24.01 m
# number_of_laps: 3.0
# m3_score: 2.66
#
# FINAL M2 + M3 SCORE:  3.7815254320577276
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.14
# Aspect Ratio: 8.25
# Motor Power: 432.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 37 Wh
# Mission 3: Banner Length (Inches)= 244.0, Banner AR = 4.0, payload = 0.86 kg, Battery Cap = 44 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.60 m/s
# n_turning: 4.38
# v_turning: 26.76 m/s
# bank_angle: 76.79 degrees
# turn_radius: 17.13 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.19
# v_turning: 26.76 m/s
# bank_angle: 71.76 degrees
# turn_radius: 24.07 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.828580502660346
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.12
# Aspect Ratio: 9.43
# Motor Power: 387.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 231.0, Banner AR = 4.0, payload = 0.77 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.90 m/s
# n_turning: 4.38
# v_turning: 27.03 m/s
# bank_angle: 76.79 degrees
# turn_radius: 17.49 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.26
# v_turning: 27.03 m/s
# bank_angle: 72.13 degrees
# turn_radius: 24.02 m
# number_of_laps: 3.0
# m3_score: 2.67
#
# FINAL M2 + M3 SCORE:  3.7901249026212502
#
# ############ General Plane Dimensions ###############
# WS: 0.90
# Chord: 0.06
# Aspect Ratio: 15.18
# Motor Power: 149.4
# CDO: 0.1565
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 7, Pucks = 1, payload = 0.30 kg, Battery Cap = 17 Wh
# Mission 3: Banner Length (Inches)= 10.0, Banner AR = 5.0, payload = 0.00 kg, Battery Cap = 17 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.265
# V_cruise: 29.06 m/s
# n_turning: 3.42
# v_turning: 27.71 m/s
# bank_angle: 73.02 degrees
# turn_radius: 23.90 m
# number_of_laps: 5.0
# m2_score: 1.17
#
# ############ MISSION 3 ##############
# CL_cruise: 0.287
# V_cruise: 21.66 m/s
# n_turning: 5.69
# v_turning: 27.71 m/s
# bank_angle: 79.88 degrees
# turn_radius: 13.97 m
# number_of_laps: 5.0
# m3_score: 2.05
#
# FINAL M2 + M3 SCORE:  3.215763904671717
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.21
# Aspect Ratio: 5.53
# Motor Power: 662.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 41 Wh
# Mission 3: Banner Length (Inches)= 302.0, Banner AR = 4.0, payload = 1.32 kg, Battery Cap = 69 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 27.71 m/s
# n_turning: 4.33
# v_turning: 25.79 m/s
# bank_angle: 76.66 degrees
# turn_radius: 16.09 m
# number_of_laps: 2.0
# m2_score: 1.08
#
# ############ MISSION 3 ##############
# CL_cruise: 0.511
# V_cruise: 20.94 m/s
# n_turning: 2.97
# v_turning: 25.79 m/s
# bank_angle: 70.30 degrees
# turn_radius: 24.28 m
# number_of_laps: 3.0
# m3_score: 2.88
#
# FINAL M2 + M3 SCORE:  3.96031011026351
#
# ############ General Plane Dimensions ###############
# WS: 1.52
# Chord: 0.06
# Aspect Ratio: 26.51
# Motor Power: 244.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 28 Wh
# Mission 3: Banner Length (Inches)= 205.0, Banner AR = 5.0, payload = 0.49 kg, Battery Cap = 23 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.217
# V_cruise: 29.25 m/s
# n_turning: 4.34
# v_turning: 28.41 m/s
# bank_angle: 76.67 degrees
# turn_radius: 19.49 m
# number_of_laps: 6.0
# m2_score: 1.16
#
# ############ MISSION 3 ##############
# CL_cruise: 0.477
# V_cruise: 21.68 m/s
# n_turning: 3.60
# v_turning: 28.41 m/s
# bank_angle: 73.87 degrees
# turn_radius: 23.79 m
# number_of_laps: 3.0
# m3_score: 2.56
#
# FINAL M2 + M3 SCORE:  3.7155752280041034
#
# ############ General Plane Dimensions ###############
# WS: 1.52
# Chord: 0.09
# Aspect Ratio: 16.70
# Motor Power: 387.3
# CDO: 0.1565
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 7, Pucks = 1, payload = 0.30 kg, Battery Cap = 44 Wh
# Mission 3: Banner Length (Inches)= 231.0, Banner AR = 4.0, payload = 0.77 kg, Battery Cap = 16 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 29.08 m/s
# n_turning: 4.58
# v_turning: 27.83 m/s
# bank_angle: 77.39 degrees
# turn_radius: 17.67 m
# number_of_laps: 6.0
# m2_score: 1.16
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.12 m/s
# n_turning: 3.45
# v_turning: 27.83 m/s
# bank_angle: 73.17 degrees
# turn_radius: 23.88 m
# number_of_laps: 1.0
# m3_score: 2.21
#
# FINAL M2 + M3 SCORE:  3.3685874267836633
#
# ############ General Plane Dimensions ###############
# WS: 1.18
# Chord: 0.13
# Aspect Ratio: 9.08
# Motor Power: 432.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 41 Wh
# Mission 3: Banner Length (Inches)= 244.0, Banner AR = 4.0, payload = 0.86 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.60 m/s
# n_turning: 4.44
# v_turning: 26.96 m/s
# bank_angle: 76.99 degrees
# turn_radius: 17.12 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.24
# v_turning: 26.96 m/s
# bank_angle: 72.03 degrees
# turn_radius: 24.03 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.816557073082559
#
# ############ General Plane Dimensions ###############
# WS: 1.26
# Chord: 0.13
# Aspect Ratio: 10.00
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 32 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.52
# v_turning: 27.14 m/s
# bank_angle: 77.22 degrees
# turn_radius: 17.03 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.08 m/s
# n_turning: 3.29
# v_turning: 27.14 m/s
# bank_angle: 72.28 degrees
# turn_radius: 24.00 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.8046355727409704
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.24
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 45 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.39
# v_turning: 26.76 m/s
# bank_angle: 76.83 degrees
# turn_radius: 17.08 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.19
# v_turning: 26.76 m/s
# bank_angle: 71.75 degrees
# turn_radius: 24.07 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.8404936908304608
#
# ############ General Plane Dimensions ###############
# WS: 1.34
# Chord: 0.12
# Aspect Ratio: 11.40
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 48 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 36 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.59
# v_turning: 27.38 m/s
# bank_angle: 77.43 degrees
# turn_radius: 17.04 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.11 m/s
# n_turning: 3.34
# v_turning: 27.38 m/s
# bank_angle: 72.59 degrees
# turn_radius: 23.95 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.5825172370268956
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.13
# Aspect Ratio: 9.00
# Motor Power: 414.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 43 Wh
# Mission 3: Banner Length (Inches)= 239.0, Banner AR = 4.0, payload = 0.83 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.71 m/s
# n_turning: 4.40
# v_turning: 26.94 m/s
# bank_angle: 76.87 degrees
# turn_radius: 17.26 m
# number_of_laps: 5.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.06 m/s
# n_turning: 3.24
# v_turning: 26.94 m/s
# bank_angle: 72.01 degrees
# turn_radius: 24.03 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.8218663728187776
#
# ############ General Plane Dimensions ###############
# WS: 1.30
# Chord: 0.13
# Aspect Ratio: 10.16
# Motor Power: 468.3
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 42 Wh
# Mission 3: Banner Length (Inches)= 254.0, Banner AR = 4.0, payload = 0.94 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.41 m/s
# n_turning: 4.58
# v_turning: 27.17 m/s
# bank_angle: 77.37 degrees
# turn_radius: 16.86 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.29
# v_turning: 27.17 m/s
# bank_angle: 72.32 degrees
# turn_radius: 23.99 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.831859491682291
#
# ############ General Plane Dimensions ###############
# WS: 1.29
# Chord: 0.13
# Aspect Ratio: 10.14
# Motor Power: 460.9
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 50 Wh
# Mission 3: Banner Length (Inches)= 252.0, Banner AR = 4.0, payload = 0.92 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.44 m/s
# n_turning: 4.56
# v_turning: 27.17 m/s
# bank_angle: 77.34 degrees
# turn_radius: 16.91 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.29
# v_turning: 27.17 m/s
# bank_angle: 72.32 degrees
# turn_radius: 23.99 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8343946750115814
#
# ############ General Plane Dimensions ###############
# WS: 1.07
# Chord: 0.15
# Aspect Ratio: 7.25
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 44 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.30
# v_turning: 26.47 m/s
# bank_angle: 76.54 degrees
# turn_radius: 17.10 m
# number_of_laps: 5.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.508
# V_cruise: 21.02 m/s
# n_turning: 3.13
# v_turning: 26.47 m/s
# bank_angle: 71.34 degrees
# turn_radius: 24.13 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.8509270013793477
#
# ############ General Plane Dimensions ###############
# WS: 1.19
# Chord: 0.13
# Aspect Ratio: 8.86
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 42 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.46
# v_turning: 26.91 m/s
# bank_angle: 77.03 degrees
# turn_radius: 17.00 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.23
# v_turning: 26.91 m/s
# bank_angle: 71.96 degrees
# turn_radius: 24.04 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.8299603486537848
#
# ############ General Plane Dimensions ###############
# WS: 1.13
# Chord: 0.14
# Aspect Ratio: 8.11
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 30 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.38
# v_turning: 26.73 m/s
# bank_angle: 76.81 degrees
# turn_radius: 17.06 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.04 m/s
# n_turning: 3.19
# v_turning: 26.73 m/s
# bank_angle: 71.70 degrees
# turn_radius: 24.07 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.821409267695576
#
# ############ General Plane Dimensions ###############
# WS: 1.22
# Chord: 0.13
# Aspect Ratio: 9.30
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 41 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 43 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.48
# v_turning: 27.01 m/s
# bank_angle: 77.11 degrees
# turn_radius: 17.01 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.25
# v_turning: 27.01 m/s
# bank_angle: 72.10 degrees
# turn_radius: 24.02 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8248884433013717
#
# ############ General Plane Dimensions ###############
# WS: 1.30
# Chord: 0.12
# Aspect Ratio: 10.60
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 50 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 43 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.56
# v_turning: 27.25 m/s
# bank_angle: 77.34 degrees
# turn_radius: 17.00 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.31
# v_turning: 27.25 m/s
# bank_angle: 72.42 degrees
# turn_radius: 23.98 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.8370950109262747
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.30
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.39
# v_turning: 26.78 m/s
# bank_angle: 76.84 degrees
# turn_radius: 17.08 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.20
# v_turning: 26.78 m/s
# bank_angle: 71.77 degrees
# turn_radius: 24.06 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.817019340534454
#
# ############ General Plane Dimensions ###############
# WS: 1.31
# Chord: 0.12
# Aspect Ratio: 10.83
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 25 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.57
# v_turning: 27.29 m/s
# bank_angle: 77.36 degrees
# turn_radius: 17.02 m
# number_of_laps: 2.0
# m2_score: 1.09
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.10 m/s
# n_turning: 3.32
# v_turning: 27.29 m/s
# bank_angle: 72.47 degrees
# turn_radius: 23.97 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.784220641308978
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.14
# Aspect Ratio: 8.30
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 21 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 41 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.40
# v_turning: 26.78 m/s
# bank_angle: 76.86 degrees
# turn_radius: 17.06 m
# number_of_laps: 1.0
# m2_score: 1.07
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.20
# v_turning: 26.78 m/s
# bank_angle: 71.77 degrees
# turn_radius: 24.06 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.7883937377252463
#
# ############ General Plane Dimensions ###############
# WS: 1.04
# Chord: 0.15
# Aspect Ratio: 6.88
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 50 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 44 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.26
# v_turning: 26.35 m/s
# bank_angle: 76.43 degrees
# turn_radius: 17.09 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.508
# V_cruise: 21.00 m/s
# n_turning: 3.10
# v_turning: 26.35 m/s
# bank_angle: 71.16 degrees
# turn_radius: 24.15 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.8655645208322316
#
# ############ General Plane Dimensions ###############
# WS: 1.27
# Chord: 0.13
# Aspect Ratio: 10.08
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 45 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 39 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.53
# v_turning: 27.16 m/s
# bank_angle: 77.26 degrees
# turn_radius: 17.00 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.08 m/s
# n_turning: 3.29
# v_turning: 27.16 m/s
# bank_angle: 72.30 degrees
# turn_radius: 23.99 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.830663881202031
#
# ############ General Plane Dimensions ###############
# WS: 1.40
# Chord: 0.11
# Aspect Ratio: 12.25
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 36 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 31 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.65
# v_turning: 27.49 m/s
# bank_angle: 77.57 degrees
# turn_radius: 16.98 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.12 m/s
# n_turning: 3.37
# v_turning: 27.49 m/s
# bank_angle: 72.74 degrees
# turn_radius: 23.93 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.5762196165872986
#
# ############ General Plane Dimensions ###############
# WS: 0.99
# Chord: 0.16
# Aspect Ratio: 6.10
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 46 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 42 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.17
# v_turning: 26.05 m/s
# bank_angle: 76.13 degrees
# turn_radius: 17.08 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.510
# V_cruise: 20.97 m/s
# n_turning: 3.03
# v_turning: 26.05 m/s
# bank_angle: 70.71 degrees
# turn_radius: 24.22 m
# number_of_laps: 3.0
# m3_score: 2.74
#
# FINAL M2 + M3 SCORE:  3.8650802223594267
#
# ############ General Plane Dimensions ###############
# WS: 1.19
# Chord: 0.13
# Aspect Ratio: 9.02
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 27 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 43 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.46
# v_turning: 26.95 m/s
# bank_angle: 77.03 degrees
# turn_radius: 17.04 m
# number_of_laps: 2.0
# m2_score: 1.09
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.06 m/s
# n_turning: 3.24
# v_turning: 26.95 m/s
# bank_angle: 72.01 degrees
# turn_radius: 24.03 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.7986475818603918
#
# ############ General Plane Dimensions ###############
# WS: 1.09
# Chord: 0.14
# Aspect Ratio: 7.74
# Motor Power: 432.1
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 38 Wh
# Mission 3: Banner Length (Inches)= 244.0, Banner AR = 4.0, payload = 0.86 kg, Battery Cap = 43 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.60 m/s
# n_turning: 4.33
# v_turning: 26.62 m/s
# bank_angle: 76.65 degrees
# turn_radius: 17.14 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.16
# v_turning: 26.62 m/s
# bank_angle: 71.56 degrees
# turn_radius: 24.09 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.8307774870229934
#
# ############ General Plane Dimensions ###############
# WS: 1.41
# Chord: 0.11
# Aspect Ratio: 12.31
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 50 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 37 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.65
# v_turning: 27.50 m/s
# bank_angle: 77.59 degrees
# turn_radius: 16.96 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.12 m/s
# n_turning: 3.37
# v_turning: 27.50 m/s
# bank_angle: 72.75 degrees
# turn_radius: 23.93 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.5963347492631588
#
# ############ General Plane Dimensions ###############
# WS: 1.25
# Chord: 0.13
# Aspect Ratio: 9.95
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 36 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.51
# v_turning: 27.14 m/s
# bank_angle: 77.20 degrees
# turn_radius: 17.06 m
# number_of_laps: 4.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.08 m/s
# n_turning: 3.28
# v_turning: 27.14 m/s
# bank_angle: 72.27 degrees
# turn_radius: 24.00 m
# number_of_laps: 4.0
# m3_score: 2.94
#
# FINAL M2 + M3 SCORE:  4.053316669127365
#
# ############ General Plane Dimensions ###############
# WS: 1.18
# Chord: 0.13
# Aspect Ratio: 8.87
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 33 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 38 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.45
# v_turning: 26.91 m/s
# bank_angle: 77.00 degrees
# turn_radius: 17.05 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.23
# v_turning: 26.91 m/s
# bank_angle: 71.97 degrees
# turn_radius: 24.04 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8136178247189942
#
# ############ General Plane Dimensions ###############
# WS: 1.25
# Chord: 0.13
# ...
# V_cruise: 28.56 m/s
# n_turning: 4.67
# v_turning: 27.59 m/s
# bank_angle: 77.63 degrees
# turn_radius: 17.03 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.502
# V_cruise: 21.12 m/s
# n_turning: 3.40
# v_turning: 27.59 m/s
# bank_angle: 72.87 degrees
# turn_radius: 23.92 m
# number_of_laps: 3.0
# m3_score: 2.68
#
# FINAL M2 + M3 SCORE:  3.7851122511995015
#
# ############ General Plane Dimensions ###############
# WS: 1.26
# Chord: 0.13
# Aspect Ratio: 9.94
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 44 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 34 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.52
# v_turning: 27.13 m/s
# bank_angle: 77.23 degrees
# turn_radius: 17.01 m
# number_of_laps: 5.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.08 m/s
# n_turning: 3.28
# v_turning: 27.13 m/s
# bank_angle: 72.27 degrees
# turn_radius: 24.00 m
# number_of_laps: 2.0
# m3_score: 2.47
#
# FINAL M2 + M3 SCORE:  3.596311129064317
#
# ############ General Plane Dimensions ###############
# WS: 1.39
# Chord: 0.12
# Aspect Ratio: 12.00
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 51 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 33 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.64
# v_turning: 27.46 m/s
# bank_angle: 77.56 degrees
# turn_radius: 16.96 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.11 m/s
# n_turning: 3.36
# v_turning: 27.46 m/s
# bank_angle: 72.70 degrees
# turn_radius: 23.94 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.595553488224877
#
# ############ General Plane Dimensions ###############
# WS: 1.49
# Chord: 0.11
# Aspect Ratio: 13.81
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 45 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 33 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.71
# v_turning: 27.68 m/s
# bank_angle: 77.75 degrees
# turn_radius: 16.95 m
# number_of_laps: 5.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.502
# V_cruise: 21.13 m/s
# n_turning: 3.42
# v_turning: 27.68 m/s
# bank_angle: 72.98 degrees
# turn_radius: 23.90 m
# number_of_laps: 2.0
# m3_score: 2.45
#
# FINAL M2 + M3 SCORE:  3.5797338520023794
#
# ############ General Plane Dimensions ###############
# WS: 1.11
# Chord: 0.14
# Aspect Ratio: 7.91
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 34 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 36 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.36
# v_turning: 26.67 m/s
# bank_angle: 76.74 degrees
# turn_radius: 17.09 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.04 m/s
# n_turning: 3.17
# v_turning: 26.67 m/s
# bank_angle: 71.63 degrees
# turn_radius: 24.09 m
# number_of_laps: 2.0
# m3_score: 2.48
#
# FINAL M2 + M3 SCORE:  3.5798412072407446
#
# ############ General Plane Dimensions ###############
# WS: 1.22
# Chord: 0.13
# Aspect Ratio: 9.61
# Motor Power: 435.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 22 Wh
# Mission 3: Banner Length (Inches)= 245.0, Banner AR = 4.0, payload = 0.87 kg, Battery Cap = 49 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.58 m/s
# n_turning: 4.48
# v_turning: 27.07 m/s
# bank_angle: 77.11 degrees
# turn_radius: 17.09 m
# number_of_laps: 2.0
# m2_score: 1.09
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.08 m/s
# n_turning: 3.27
# v_turning: 27.07 m/s
# bank_angle: 72.18 degrees
# turn_radius: 24.01 m
# number_of_laps: 4.0
# m3_score: 2.94
#
# FINAL M2 + M3 SCORE:  4.025891827925048
#
# ############ General Plane Dimensions ###############
# WS: 1.06
# Chord: 0.15
# Aspect Ratio: 7.19
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 39 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 40 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.29
# v_turning: 26.46 m/s
# bank_angle: 76.52 degrees
# turn_radius: 17.10 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.508
# V_cruise: 21.01 m/s
# n_turning: 3.12
# v_turning: 26.46 m/s
# bank_angle: 71.32 degrees
# turn_radius: 24.13 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.8394821366346257
#
# ############ General Plane Dimensions ###############
# WS: 1.29
# Chord: 0.12
# Aspect Ratio: 10.55
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 42 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.55
# v_turning: 27.24 m/s
# bank_angle: 77.32 degrees
# turn_radius: 17.02 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.31
# v_turning: 27.24 m/s
# bank_angle: 72.41 degrees
# turn_radius: 23.98 m
# number_of_laps: 4.0
# m3_score: 2.93
#
# FINAL M2 + M3 SCORE:  4.045193012290659
#
# ############ General Plane Dimensions ###############
# WS: 1.21
# Chord: 0.13
# Aspect Ratio: 9.25
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 32 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 40 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.47
# v_turning: 27.00 m/s
# bank_angle: 77.08 degrees
# turn_radius: 17.04 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.505
# V_cruise: 21.07 m/s
# n_turning: 3.25
# v_turning: 27.00 m/s
# bank_angle: 72.08 degrees
# turn_radius: 24.02 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.810955332858765
#
# ############ General Plane Dimensions ###############
# WS: 1.28
# Chord: 0.12
# Aspect Ratio: 10.45
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 41 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 47 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.54
# v_turning: 27.22 m/s
# bank_angle: 77.28 degrees
# turn_radius: 17.05 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.31
# v_turning: 27.22 m/s
# bank_angle: 72.39 degrees
# turn_radius: 23.98 m
# number_of_laps: 4.0
# m3_score: 2.93
#
# FINAL M2 + M3 SCORE:  4.046291995116616
#
# ############ General Plane Dimensions ###############
# WS: 1.30
# Chord: 0.12
# Aspect Ratio: 10.60
# Motor Power: 446.4
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 47 Wh
# Mission 3: Banner Length (Inches)= 248.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 44 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.52 m/s
# n_turning: 4.56
# v_turning: 27.25 m/s
# bank_angle: 77.34 degrees
# turn_radius: 17.00 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.09 m/s
# n_turning: 3.31
# v_turning: 27.25 m/s
# bank_angle: 72.42 degrees
# turn_radius: 23.98 m
# number_of_laps: 3.0
# m3_score: 2.70
#
# FINAL M2 + M3 SCORE:  3.8256711004407187
#
# ############ General Plane Dimensions ###############
# WS: 1.38
# Chord: 0.11
# Aspect Ratio: 12.05
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 29 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 36 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.63
# v_turning: 27.47 m/s
# bank_angle: 77.53 degrees
# turn_radius: 17.01 m
# number_of_laps: 2.0
# m2_score: 1.09
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.11 m/s
# n_turning: 3.36
# v_turning: 27.47 m/s
# bank_angle: 72.71 degrees
# turn_radius: 23.94 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.5465777282393764
#
# ############ General Plane Dimensions ###############
# WS: 1.01
# Chord: 0.16
# Aspect Ratio: 6.47
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 35 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.21
# v_turning: 26.20 m/s
# bank_angle: 76.25 degrees
# turn_radius: 17.12 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.509
# V_cruise: 20.99 m/s
# n_turning: 3.06
# v_turning: 26.20 m/s
# bank_angle: 70.94 degrees
# turn_radius: 24.18 m
# number_of_laps: 3.0
# m3_score: 2.73
#
# FINAL M2 + M3 SCORE:  3.832292489802809
#
# ############ General Plane Dimensions ###############
# WS: 1.14
# Chord: 0.14
# Aspect Ratio: 8.27
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 30 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 26 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.40
# v_turning: 26.77 m/s
# bank_angle: 76.85 degrees
# turn_radius: 17.06 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.20
# v_turning: 26.77 m/s
# bank_angle: 71.76 degrees
# turn_radius: 24.07 m
# number_of_laps: 1.0
# m3_score: 2.24
#
# FINAL M2 + M3 SCORE:  3.3420714602399606
#
# ############ General Plane Dimensions ###############
# WS: 1.15
# Chord: 0.14
# Aspect Ratio: 8.51
# Motor Power: 435.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 29 Wh
# Mission 3: Banner Length (Inches)= 245.0, Banner AR = 4.0, payload = 0.87 kg, Battery Cap = 38 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.58 m/s
# n_turning: 4.40
# v_turning: 26.83 m/s
# bank_angle: 76.88 degrees
# turn_radius: 17.10 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.05 m/s
# n_turning: 3.21
# v_turning: 26.83 m/s
# bank_angle: 71.85 degrees
# turn_radius: 24.05 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8158316297511443
#
# ############ General Plane Dimensions ###############
# WS: 1.17
# Chord: 0.13
# Aspect Ratio: 8.66
# Motor Power: 439.2
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 41 Wh
# Mission 3: Banner Length (Inches)= 246.0, Banner AR = 4.0, payload = 0.88 kg, Battery Cap = 37 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.56 m/s
# n_turning: 4.42
# v_turning: 26.86 m/s
# bank_angle: 76.93 degrees
# turn_radius: 17.07 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.22
# v_turning: 26.86 m/s
# bank_angle: 71.90 degrees
# turn_radius: 24.05 m
# number_of_laps: 3.0
# m3_score: 2.71
#
# FINAL M2 + M3 SCORE:  3.8254247641764016
#
# ############ General Plane Dimensions ###############
# WS: 1.05
# Chord: 0.15
# Aspect Ratio: 6.88
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 36 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 25 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.27
# v_turning: 26.35 m/s
# bank_angle: 76.47 degrees
# turn_radius: 17.04 m
# number_of_laps: 3.0
# m2_score: 1.10
#
# ############ MISSION 3 ##############
# CL_cruise: 0.508
# V_cruise: 21.00 m/s
# n_turning: 3.10
# v_turning: 26.35 m/s
# bank_angle: 71.17 degrees
# turn_radius: 24.15 m
# number_of_laps: 1.0
# m3_score: 2.25
#
# FINAL M2 + M3 SCORE:  3.345789789576788
#
# ############ General Plane Dimensions ###############
# WS: 1.33
# Chord: 0.12
# Aspect Ratio: 10.94
# Motor Power: 453.6
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 51 Wh
# Mission 3: Banner Length (Inches)= 250.0, Banner AR = 4.0, payload = 0.91 kg, Battery Cap = 26 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.48 m/s
# n_turning: 4.60
# v_turning: 27.31 m/s
# bank_angle: 77.43 degrees
# turn_radius: 16.95 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.504
# V_cruise: 21.10 m/s
# n_turning: 3.33
# v_turning: 27.31 m/s
# bank_angle: 72.50 degrees
# turn_radius: 23.97 m
# number_of_laps: 1.0
# m3_score: 2.24
#
# FINAL M2 + M3 SCORE:  3.368520998250283
#
# ############ General Plane Dimensions ###############
# WS: 1.17
# Chord: 0.14
# Aspect Ratio: 8.66
# Motor Power: 442.8
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 46 Wh
# Mission 3: Banner Length (Inches)= 247.0, Banner AR = 4.0, payload = 0.89 kg, Battery Cap = 42 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.54 m/s
# n_turning: 4.43
# v_turning: 26.86 m/s
# bank_angle: 76.95 degrees
# turn_radius: 17.05 m
# number_of_laps: 5.0
# m2_score: 1.12
#
# ############ MISSION 3 ##############
# CL_cruise: 0.506
# V_cruise: 21.06 m/s
# n_turning: 3.22
# v_turning: 26.86 m/s
# bank_angle: 71.90 degrees
# turn_radius: 24.05 m
# number_of_laps: 3.0
# m3_score: 2.72
#
# FINAL M2 + M3 SCORE:  3.8395345994691246
#
# ############ General Plane Dimensions ###############
# WS: 1.43
# Chord: 0.11
# Aspect Ratio: 12.75
# Motor Power: 450.0
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 51 Wh
# Mission 3: Banner Length (Inches)= 249.0, Banner AR = 4.0, payload = 0.90 kg, Battery Cap = 31 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.50 m/s
# n_turning: 4.67
# v_turning: 27.56 m/s
# bank_angle: 77.64 degrees
# turn_radius: 16.96 m
# number_of_laps: 6.0
# m2_score: 1.13
#
# ############ MISSION 3 ##############
# CL_cruise: 0.503
# V_cruise: 21.12 m/s
# n_turning: 3.39
# v_turning: 27.56 m/s
# bank_angle: 72.83 degrees
# turn_radius: 23.92 m
# number_of_laps: 2.0
# m3_score: 2.46
#
# FINAL M2 + M3 SCORE:  3.593906841081327
# Best parameters found: [1.1016830258049493, np.int64(1), np.int64(6), np.int64(245), np.int64(4), np.int64(220), np.int64(247)]
#
# ############ General Plane Dimensions ###############
# WS: 1.10
# Chord: 0.14
# Aspect Ratio: 7.80
# Motor Power: 435.7
# CDO: 0.1545
#
# ############ MISSION INPUTS ###############
# Mission 2: Ducks = 6, Pucks = 1, payload = 0.28 kg, Battery Cap = 42 Wh
# Mission 3: Banner Length (Inches)= 245.0, Banner AR = 4.0, payload = 0.87 kg, Battery Cap = 46 Wh
#
# ############ MISSION 2 ##############
# CL_cruise: 0.200
# V_cruise: 28.58 m/s
# n_turning: 4.34
# v_turning: 26.64 m/s
# bank_angle: 76.69 degrees
# turn_radius: 17.12 m
# number_of_laps: 4.0
# m2_score: 1.11
#
# ############ MISSION 3 ##############
# CL_cruise: 0.507
# V_cruise: 21.03 m/s
# n_turning: 3.17
# v_turning: 26.64 m/s
# bank_angle: 71.58 degrees
# turn_radius: 24.09 m
# number_of_laps: 4.0
# m3_score: 2.96
#
# FINAL M2 + M3 SCORE:  4.070588416706626
# np.float64(-4.070588416706626)
